# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df= pd.read_csv("Unemployment_in_India.csv")

# %%
print(df.head())
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural

# %%
df.tail()
# Out:
#     Region  Date  Frequency   Estimated Unemployment Rate (%)  \
# 763    NaN   NaN        NaN                               NaN
# 764    NaN   NaN        NaN                               NaN
# 765    NaN   NaN        NaN                               NaN
# 766    NaN   NaN        NaN                               NaN
# 767    NaN   NaN        NaN                               NaN
#
#       Estimated Employed   Estimated Labour Participation Rate (%) Area
# 763                  NaN                                       NaN  NaN
# 764                  NaN                                       NaN  NaN
# 765                  NaN                                       NaN  NaN
# 766                  NaN                                       NaN  NaN
# 767                  NaN                                       NaN  NaN

# %%
df.shape
# Out:
# (768, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    740 non-null    object
#  1    Date                                     740 non-null    object
#  2    Frequency                                740 non-null    object
#  3    Estimated Unemployment Rate (%)          740 non-null    float64
#  4    Estimated Employed                       740 non-null    float64
#  5    Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                      740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 42.1+ KB

# %%
df.isnull().sum
# Out:
# <bound method DataFrame.sum of      Region   Date   Frequency   Estimated Unemployment Rate (%)  \
# 0     False  False       False                             False
# 1     False  False       False                             False
# 2     False  False       False                             False
# 3     False  False       False                             False
# 4     False  False       False                             False
# ..      ...    ...         ...                               ...
# 763    True   True        True                              True
# 764    True   True        True                              True
# 765    True   True        True                              True
# 766    True   True        True                              True
# 767    True   True        True                              True
#
#       Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0                  False                                     False  False
# ...

# %%
round(df.isnull().sum()/df.shape[0]*100,2)
# Out:
# Region                                      3.65
#  Date                                       3.65
#  Frequency                                  3.65
#  Estimated Unemployment Rate (%)            3.65
#  Estimated Employed                         3.65
#  Estimated Labour Participation Rate (%)    3.65
# Area                                        3.65
# dtype: float64

# %%
c=df.dropna(inplace = True)
print(c)
# Out:
# None

# %%
df.shape
# Out:
# (740, 7)

# %%
df.isnull().sum()/df.shape[0]
# Out:
# Region                                      0.0
#  Date                                       0.0
#  Frequency                                  0.0
#  Estimated Unemployment Rate (%)            0.0
#  Estimated Employed                         0.0
#  Estimated Labour Participation Rate (%)    0.0
# Area                                        0.0
# dtype: float64

# %%
print(df.columns)
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
print(data.head())
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural

# %%
df = df.rename(columns={ 
    ' Date': 'Date',
    ' Frequency': 'Frequency',
    ' Estimated Unemployment Rate (%)': 'Est_Unemp_Rate',
    ' Estimated Employed': 'Est_Emp_Rate',
    ' Estimated Labour Participation Rate (%)': 'Est_Labour_Rate'
}).reset_index(drop=True)

df['Est_Emp_Rate'] = round((df['Est_Emp_Rate']/1000000),2)
df.head()
# Out:
#            Region         Date Frequency  Est_Unemp_Rate  Est_Emp_Rate  \
# 0  Andhra Pradesh   31-05-2019   Monthly            3.65         12.00
# 1  Andhra Pradesh   30-06-2019   Monthly            3.05         11.76
# 2  Andhra Pradesh   31-07-2019   Monthly            3.75         12.09
# 3  Andhra Pradesh   31-08-2019   Monthly            3.32         12.29
# 4  Andhra Pradesh   30-09-2019   Monthly            5.17         12.26
#
#    Est_Labour_Rate   Area
# 0            43.24  Rural
# 1            42.05  Rural
# 2            43.50  Rural
# 3            43.97  Rural
# 4            44.68  Rural

# %%
data['Est_Emp_Rate'] = round((data['Est_Emp_Rate']/1000000),2)
data.head()
# Out:
#            Region Frequency  Est_Unemp_Rate  Est_Emp_Rate  Est_Labour_Rate  \
# 0  Andhra Pradesh   Monthly            3.65         12.00            43.24
# 1  Andhra Pradesh   Monthly            3.05         11.76            42.05
# 2  Andhra Pradesh   Monthly            3.75         12.09            43.50
# 3  Andhra Pradesh   Monthly            3.32         12.29            43.97
# 4  Andhra Pradesh   Monthly            5.17         12.26            44.68
#
#     Area
# 0  Rural
# 1  Rural
# 2  Rural
# 3  Rural
# 4  Rural

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 740 entries, 0 to 739
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Region           740 non-null    object
#  1   Date             740 non-null    datetime64[ns]
#  2   Frequency        740 non-null    object
#  3   Est_Unemp_Rate   740 non-null    float64
#  4   Est_Emp_Rate     740 non-null    float64
#  5   Est_Labour_Rate  740 non-null    float64
#  6   Area             740 non-null    object
# dtypes: datetime64[ns](1), float64(3), object(3)
# memory usage: 40.6+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.Frequency.value_counts()
# Out:
# Frequency
# Monthly     381
#  Monthly    359
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 740 entries, 0 to 739
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Region           740 non-null    object
#  1   Date             740 non-null    datetime64[ns]
#  2   Frequency        740 non-null    object
#  3   Est_Unemp_Rate   740 non-null    float64
#  4   Est_Emp_Rate     740 non-null    float64
#  5   Est_Labour_Rate  740 non-null    float64
#  6   Area             740 non-null    object
# dtypes: datetime64[ns](1), float64(3), object(3)
# memory usage: 40.6+ KB

# %%
df = df.drop(['Frequency'],axis = 1)
df.shape
# Out:
# (740, 6)

# %%
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df.head()
# Out:
#            Region       Date  Est_Unemp_Rate  Est_Emp_Rate  Est_Labour_Rate  \
# 0  Andhra Pradesh 2019-05-31            3.65         12.00            43.24
# 1  Andhra Pradesh 2019-06-30            3.05         11.76            42.05
# 2  Andhra Pradesh 2019-07-31            3.75         12.09            43.50
# 3  Andhra Pradesh 2019-08-31            3.32         12.29            43.97
# 4  Andhra Pradesh 2019-09-30            5.17         12.26            44.68
#
#     Area  Year  Month
# 0  Rural  2019      5
# 1  Rural  2019      6
# 2  Rural  2019      7
# 3  Rural  2019      8
# 4  Rural  2019      9

# %%
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['Est_Unemp_Rate'], marker='o')
plt.title('Unemployment Rate in India Over Time')
plt.xlabel('Date')
plt.ylabel('Estimated Unemployment Rate (%)')
plt.grid(True)
plt.show()

# %%
df.Area.value_counts(normalize = True)*100
# Out:
# Area
# Urban    51.486486
# Rural    48.513514
# Name: proportion, dtype: float64

# %%
df.Region.value_counts()
# Out:
# Region
# Andhra Pradesh      28
# Kerala              28
# West Bengal         28
# Uttar Pradesh       28
# Tripura             28
# Telangana           28
# Tamil Nadu          28
# Rajasthan           28
# Punjab              28
# Odisha              28
# Madhya Pradesh      28
# Maharashtra         28
# Karnataka           28
# Jharkhand           28
# Himachal Pradesh    28
# Haryana             28
# Gujarat             28
# Delhi               28
# Chhattisgarh        28
# Bihar               28
# Meghalaya           27
# Uttarakhand         27
# Assam               26
# Puducherry          26
# Goa                 24
# Jammu & Kashmir     21
# Sikkim              17
# Chandigarh          12
# Name: count, dtype: int64

# %%
numeric_data = data.select_dtypes(include='number')

# %%
plt.style.use("ggplot")

plt.figure(figsize=(10, 10))
sns.heatmap(numeric_data.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
plt.style.use("dark_background")

plt.figure(figsize=(10, 6))
sns.histplot(x="Est_Emp_Rate", hue="Area", data=data, kde=True, palette="Set2")
plt.title("Histogram of Estimated Employment Rate by Area")
plt.xlabel("Estimated Employment Rate")
plt.ylabel("Count")
plt.show()

# %%
plt.style.use("dark_background")

plt.figure(figsize=(10, 6))
sns.histplot(x="Est_Unemp_Rate", hue="Area", data=data, kde=True, palette="Set2")
plt.title("Histogram of Estimated Unemployment Rate by Area")
plt.xlabel("Estimated Unemployment Rate")
plt.ylabel("Count")
plt.show()

# %%
data = data[['Region', 'Est_Unemp_Rate']]
sns.boxplot(x='Region', y='Est_Unemp_Rate', data=data)
plt.xlabel('Region')
plt.ylabel('Estimated Unemployment Rate')
plt.title('Box Plot of Estimated Unemployment Rate by Region')
plt.xticks(rotation=90)
plt.show()

# %%
data = data[['Region', 'Est_Unemp_Rate']]
data_grouped = data.groupby('Region')['Est_Unemp_Rate'].mean()
data_grouped.plot(kind='bar')
plt.xlabel('Region')
plt.ylabel('Mean Estimated Unemployment Rate')
plt.title('Mean Estimated Unemployment Rate by Region')
plt.show()

# %%
data = data[['Region', 'Est_Unemp_Rate']]
data_grouped = data.groupby('Region')['Est_Unemp_Rate'].sum()
data_grouped.plot(kind='pie', autopct='%1.1f%%')
plt.title('Distribution of Estimated Unemployment Rate by Region')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
